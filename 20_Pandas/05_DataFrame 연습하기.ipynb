# %% [markdown]
# # 5. DataFrame 연습하기

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 5-1. 데이터 가져오기

# %%
df = pd.read_csv('data/korean-idol.csv')
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %% [markdown]
# ## 5-2. 데이터 살펴보기

# %%
df.shape
# Out:
# (15, 8)

# %%
df.head()
# Out:
#      이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0    지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 1  지드래곤     빅뱅   YG  남자  1988-08-18  177.0   A   9916947
# 2  강다니엘    NaN  커넥트  남자  1996-12-10  180.0   A   8273745
# 3     뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 4    화사    마마무  RBW  여자  1995-07-23  162.1   A   7650928

# %%
df.tail()
# Out:
#      이름     그룹   소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 10   태연   소녀시대    SM  여자  1989-03-09    NaN   A  3918661
# 11  차은우   아스트로  판타지오  남자  1997-03-30  183.0   B  3506027
# 12   백호   뉴이스트  플레디스  남자  1995-07-21  175.0  AB  3301654
# 13   JR   뉴이스트  플레디스  남자  1995-06-08  176.0   O  3274137
# 14   슈가  방탄소년단   빅히트  남자  1993-03-09  174.0   O  2925442

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   이름       15 non-null     object
#  1   그룹       14 non-null     object
#  2   소속사      15 non-null     object
#  3   성별       15 non-null     object
#  4   생년월일     15 non-null     object
#  5   키        13 non-null     float64
#  6   혈액형      15 non-null     object
#  7   브랜드평판지수  15 non-null     int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.1+ KB

# %%
df.describe()
# Out:
#                 키       브랜드평판지수
# count   13.000000  1.500000e+01
# mean   175.792308  5.655856e+06
# std      5.820576  2.539068e+06
# min    162.100000  2.925442e+06
# 25%    174.000000  3.712344e+06
# 50%    177.000000  4.668615e+06
# 75%    179.200000  7.862214e+06
# max    183.000000  1.052326e+07

# %%
# index 값 증가
df.index += 1
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 1     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 2   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 3   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 4      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 5     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 6     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 7     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 8     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 9      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 10   하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 11    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 12   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 13    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 14    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %% [markdown]
# ## 5-3. 데이터 인덱싱, 슬라이싱

# %%
# 열 인덱싱
df['이름']
# Out:
# 1       지민
# 2     지드래곤
# 3     강다니엘
# 4        뷔
# 5       화사
# 6       정국
# 7       민현
# 8       소연
# 9        진
# 10     하성운
# 11      태연
# 12     차은우
# 13      백호
# 14      JR
# 15      슈가
# Name: 이름, dtype: object

# %%
df.이름
# Out:
# 1       지민
# 2     지드래곤
# 3     강다니엘
# 4        뷔
# 5       화사
# 6       정국
# 7       민현
# 8       소연
# 9        진
# 10     하성운
# 11      태연
# 12     차은우
# 13      백호
# 14      JR
# 15      슈가
# Name: 이름, dtype: object

# %%
df.loc[:, '이름']
# Out:
# 1       지민
# 2     지드래곤
# 3     강다니엘
# 4        뷔
# 5       화사
# 6       정국
# 7       민현
# 8       소연
# 9        진
# 10     하성운
# 11      태연
# 12     차은우
# 13      백호
# 14      JR
# 15      슈가
# Name: 이름, dtype: object

# %%
# 이름, 그룹 가져오기
df[['이름', '그룹']]
# Out:
#       이름     그룹
# 1     지민  방탄소년단
# 2   지드래곤     빅뱅
# 3   강다니엘    NaN
# 4      뷔  방탄소년단
# 5     화사    마마무
# 6     정국  방탄소년단
# 7     민현   뉴이스트
# 8     소연    아이들
# 9      진  방탄소년단
# 10   하성운     핫샷
# 11    태연   소녀시대
# 12   차은우   아스트로
# 13    백호   뉴이스트
# 14    JR   뉴이스트
# 15    슈가  방탄소년단

# %%
df.loc[:, ['이름', '그룹']]
# Out:
#       이름     그룹
# 1     지민  방탄소년단
# 2   지드래곤     빅뱅
# 3   강다니엘    NaN
# 4      뷔  방탄소년단
# 5     화사    마마무
# 6     정국  방탄소년단
# 7     민현   뉴이스트
# 8     소연    아이들
# 9      진  방탄소년단
# 10   하성운     핫샷
# 11    태연   소녀시대
# 12   차은우   아스트로
# 13    백호   뉴이스트
# 14    JR   뉴이스트
# 15    슈가  방탄소년단

# %%
# 행 인덱싱
df.loc[15]
# Out:
# 이름                 슈가
# 그룹              방탄소년단
# 소속사               빅히트
# 성별                 남자
# 생년월일       1993-03-09
# 키                 174
# 혈액형                 O
# 브랜드평판지수       2925442
# Name: 15, dtype: object

# %%
df.iloc[14]
# Out:
# 이름                 슈가
# 그룹              방탄소년단
# 소속사               빅히트
# 성별                 남자
# 생년월일       1993-03-09
# 키                 174
# 혈액형                 O
# 브랜드평판지수       2925442
# Name: 15, dtype: object

# %%
df.loc[[4, 15]]
# Out:
#     이름     그룹  소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 4    뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB  8073501
# 15  슈가  방탄소년단  빅히트  남자  1993-03-09  174.0   O  2925442

# %%
df.iloc[[3, 14]]
# Out:
#     이름     그룹  소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 4    뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB  8073501
# 15  슈가  방탄소년단  빅히트  남자  1993-03-09  174.0   O  2925442

# %%
df.loc[[4,15], '이름':'생년월일']
# Out:
#     이름     그룹  소속사  성별        생년월일
# 4    뷔  방탄소년단  빅히트  남자  1995-12-30
# 15  슈가  방탄소년단  빅히트  남자  1993-03-09

# %%
df.iloc[[3, 14], :5]
# Out:
#     이름     그룹  소속사  성별        생년월일
# 4    뷔  방탄소년단  빅히트  남자  1995-12-30
# 15  슈가  방탄소년단  빅히트  남자  1993-03-09

# %%
df.loc[4:9, '이름':'소속사']
# Out:
#    이름     그룹   소속사
# 4   뷔  방탄소년단   빅히트
# 5  화사    마마무   RBW
# 6  정국  방탄소년단   빅히트
# 7  민현   뉴이스트  플레디스
# 8  소연    아이들    큐브
# 9   진  방탄소년단   빅히트

# %%
df.iloc[3:9, :3]
# Out:
#    이름     그룹   소속사
# 4   뷔  방탄소년단   빅히트
# 5  화사    마마무   RBW
# 6  정국  방탄소년단   빅히트
# 7  민현   뉴이스트  플레디스
# 8  소연    아이들    큐브
# 9   진  방탄소년단   빅히트

# %%
# Boolean 인덱싱
# 소속사가 빅히트인 가수 조회하기
df[df['소속사']=='빅히트']
# Out:
#     이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 1   지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 4    뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 6   정국  방탄소년단  빅히트  남자  1997-09-01  178.0   A   5208335
# 9    진  방탄소년단  빅히트  남자  1992-12-04  179.2   O   4570308
# 15  슈가  방탄소년단  빅히트  남자  1993-03-09  174.0   O   2925442

# %%
df.loc[df['소속사'] == '빅히트']
# Out:
#     이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 1   지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 4    뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 6   정국  방탄소년단  빅히트  남자  1997-09-01  178.0   A   5208335
# 9    진  방탄소년단  빅히트  남자  1992-12-04  179.2   O   4570308
# 15  슈가  방탄소년단  빅히트  남자  1993-03-09  174.0   O   2925442

# %%
# pandas query
df.query('소속사 == "빅히트"')
# Out:
#     이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 1   지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 4    뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 6   정국  방탄소년단  빅히트  남자  1997-09-01  178.0   A   5208335
# 9    진  방탄소년단  빅히트  남자  1992-12-04  179.2   O   4570308
# 15  슈가  방탄소년단  빅히트  남자  1993-03-09  174.0   O   2925442

# %%
# 키가 180 이상인 사람 조회
df.query('키 >= 180')
# Out:
#       이름    그룹   소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 3   강다니엘   NaN   커넥트  남자  1996-12-10  180.0   A  8273745
# 7     민현  뉴이스트  플레디스  남자  1995-08-09  182.3   O  4989792
# 12   차은우  아스트로  판타지오  남자  1997-03-30  183.0   B  3506027

# %%
df.loc[df['키'] >= 180]
# Out:
#       이름    그룹   소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 3   강다니엘   NaN   커넥트  남자  1996-12-10  180.0   A  8273745
# 7     민현  뉴이스트  플레디스  남자  1995-08-09  182.3   O  4989792
# 12   차은우  아스트로  판타지오  남자  1997-03-30  183.0   B  3506027

# %%
df[df['키'] >= 180]
# Out:
#       이름    그룹   소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 3   강다니엘   NaN   커넥트  남자  1996-12-10  180.0   A  8273745
# 7     민현  뉴이스트  플레디스  남자  1995-08-09  182.3   O  4989792
# 12   차은우  아스트로  판타지오  남자  1997-03-30  183.0   B  3506027

# %%
# 소속사가 빅히트 or SM
df[(df['소속사'] == '빅히트') | (df['소속사'] == 'SM')]
# Out:
#     이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 1   지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 4    뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 6   정국  방탄소년단  빅히트  남자  1997-09-01  178.0   A   5208335
# 9    진  방탄소년단  빅히트  남자  1992-12-04  179.2   O   4570308
# 11  태연   소녀시대   SM  여자  1989-03-09    NaN   A   3918661
# 15  슈가  방탄소년단  빅히트  남자  1993-03-09  174.0   O   2925442

# %%
df.query('소속사 in ["빅히트", "SM"]')
# Out:
#     이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 1   지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 4    뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 6   정국  방탄소년단  빅히트  남자  1997-09-01  178.0   A   5208335
# 9    진  방탄소년단  빅히트  남자  1992-12-04  179.2   O   4570308
# 11  태연   소녀시대   SM  여자  1989-03-09    NaN   A   3918661
# 15  슈가  방탄소년단  빅히트  남자  1993-03-09  174.0   O   2925442

# %%
df.query('소속사 == "빅히트" | 소속사 == "SM"')
# Out:
#     이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 1   지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 4    뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 6   정국  방탄소년단  빅히트  남자  1997-09-01  178.0   A   5208335
# 9    진  방탄소년단  빅히트  남자  1992-12-04  179.2   O   4570308
# 11  태연   소녀시대   SM  여자  1989-03-09    NaN   A   3918661
# 15  슈가  방탄소년단  빅히트  남자  1993-03-09  174.0   O   2925442

# %%
df.loc[(df['소속사'] == '빅히트') | (df['소속사'] == 'SM')]
# Out:
#     이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 1   지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 4    뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 6   정국  방탄소년단  빅히트  남자  1997-09-01  178.0   A   5208335
# 9    진  방탄소년단  빅히트  남자  1992-12-04  179.2   O   4570308
# 11  태연   소녀시대   SM  여자  1989-03-09    NaN   A   3918661
# 15  슈가  방탄소년단  빅히트  남자  1993-03-09  174.0   O   2925442

# %% [markdown]
# ## 5-4. 데이터 CRUD

# %%
# 아이유행 추가
df.loc[16] = ['아이유', np.NaN, 'EDAM', '여자', '1993-05-16', 162, 'O', 9656213]
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 1     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 2   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 3   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 4      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 5     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 6     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 7     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 8     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 9      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 10   하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 11    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 12   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 13    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 14    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df = df.drop(16)
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 1     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 2   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 3   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 4      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 5     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 6     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 7     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 8     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 9      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 10   하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 11    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 12   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 13    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 14    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
# 소속사가 빅히트인 데이터 삭제
df = df.drop(df.query('소속사 == "빅히트"').index)
df
# Out:
#       이름    그룹      소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 2   지드래곤    빅뱅       YG  남자  1988-08-18  177.0   A  9916947
# 3   강다니엘   NaN      커넥트  남자  1996-12-10  180.0   A  8273745
# 5     화사   마마무      RBW  여자  1995-07-23  162.1   A  7650928
# 7     민현  뉴이스트     플레디스  남자  1995-08-09  182.3   O  4989792
# 8     소연   아이들       큐브  여자  1998-08-26    NaN   B  4668615
# 10   하성운    핫샷  스타크루이엔티  남자  1994-03-22  167.1   A  4036489
# 11    태연  소녀시대       SM  여자  1989-03-09    NaN   A  3918661
# 12   차은우  아스트로     판타지오  남자  1997-03-30  183.0   B  3506027
# 13    백호  뉴이스트     플레디스  남자  1995-07-21  175.0  AB  3301654
# 14    JR  뉴이스트     플레디스  남자  1995-06-08  176.0   O  3274137

# %%
# 열 추가
df['국적'] = "대한민국"
df
# Out:
#       이름    그룹      소속사  성별        생년월일      키 혈액형  브랜드평판지수    국적
# 2   지드래곤    빅뱅       YG  남자  1988-08-18  177.0   A  9916947  대한민국
# 3   강다니엘   NaN      커넥트  남자  1996-12-10  180.0   A  8273745  대한민국
# 5     화사   마마무      RBW  여자  1995-07-23  162.1   A  7650928  대한민국
# 7     민현  뉴이스트     플레디스  남자  1995-08-09  182.3   O  4989792  대한민국
# 8     소연   아이들       큐브  여자  1998-08-26    NaN   B  4668615  대한민국
# 10   하성운    핫샷  스타크루이엔티  남자  1994-03-22  167.1   A  4036489  대한민국
# 11    태연  소녀시대       SM  여자  1989-03-09    NaN   A  3918661  대한민국
# 12   차은우  아스트로     판타지오  남자  1997-03-30  183.0   B  3506027  대한민국
# 13    백호  뉴이스트     플레디스  남자  1995-07-21  175.0  AB  3301654  대한민국
# 14    JR  뉴이스트     플레디스  남자  1995-06-08  176.0   O  3274137  대한민국

# %%
df.drop('국적', axis=1)
# Out:
#       이름    그룹      소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 2   지드래곤    빅뱅       YG  남자  1988-08-18  177.0   A  9916947
# 3   강다니엘   NaN      커넥트  남자  1996-12-10  180.0   A  8273745
# 5     화사   마마무      RBW  여자  1995-07-23  162.1   A  7650928
# 7     민현  뉴이스트     플레디스  남자  1995-08-09  182.3   O  4989792
# 8     소연   아이들       큐브  여자  1998-08-26    NaN   B  4668615
# 10   하성운    핫샷  스타크루이엔티  남자  1994-03-22  167.1   A  4036489
# 11    태연  소녀시대       SM  여자  1989-03-09    NaN   A  3918661
# 12   차은우  아스트로     판타지오  남자  1997-03-30  183.0   B  3506027
# 13    백호  뉴이스트     플레디스  남자  1995-07-21  175.0  AB  3301654
# 14    JR  뉴이스트     플레디스  남자  1995-06-08  176.0   O  3274137

# %%
df.drop(columns='국적')
# Out:
#       이름    그룹      소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 2   지드래곤    빅뱅       YG  남자  1988-08-18  177.0   A  9916947
# 3   강다니엘   NaN      커넥트  남자  1996-12-10  180.0   A  8273745
# 5     화사   마마무      RBW  여자  1995-07-23  162.1   A  7650928
# 7     민현  뉴이스트     플레디스  남자  1995-08-09  182.3   O  4989792
# 8     소연   아이들       큐브  여자  1998-08-26    NaN   B  4668615
# 10   하성운    핫샷  스타크루이엔티  남자  1994-03-22  167.1   A  4036489
# 11    태연  소녀시대       SM  여자  1989-03-09    NaN   A  3918661
# 12   차은우  아스트로     판타지오  남자  1997-03-30  183.0   B  3506027
# 13    백호  뉴이스트     플레디스  남자  1995-07-21  175.0  AB  3301654
# 14    JR  뉴이스트     플레디스  남자  1995-06-08  176.0   O  3274137

# %%
del df['키']
df
# Out:
#       이름    그룹      소속사  성별        생년월일 혈액형  브랜드평판지수    국적
# 2   지드래곤    빅뱅       YG  남자  1988-08-18   A  9916947  대한민국
# 3   강다니엘   NaN      커넥트  남자  1996-12-10   A  8273745  대한민국
# 5     화사   마마무      RBW  여자  1995-07-23   A  7650928  대한민국
# 7     민현  뉴이스트     플레디스  남자  1995-08-09   O  4989792  대한민국
# 8     소연   아이들       큐브  여자  1998-08-26   B  4668615  대한민국
# 10   하성운    핫샷  스타크루이엔티  남자  1994-03-22   A  4036489  대한민국
# 11    태연  소녀시대       SM  여자  1989-03-09   A  3918661  대한민국
# 12   차은우  아스트로     판타지오  남자  1997-03-30   B  3506027  대한민국
# 13    백호  뉴이스트     플레디스  남자  1995-07-21  AB  3301654  대한민국
# 14    JR  뉴이스트     플레디스  남자  1995-06-08   O  3274137  대한민국
