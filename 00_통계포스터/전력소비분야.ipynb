# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
d = pd.read_csv("./Data/csv_8_2.csv")

# %%
d
# Out:
#        Unnamed: 0          원자력           석탄          LNG         신재생  \
# 0       서울  Seoul           -            -     4,625,854     413,218
# 1       부산  Busan   33,757,935       21,450    6,391,249     339,967
# 2       대구  Daegu           -         2,355    2,352,814     136,458
# 3     인천  Incheon           -    32,031,780   23,592,635   1,374,643
# 4     광주  Gwangju           -            -       350,000     242,293
# 5     대전  Daejeon           -            -        90,363      45,447
# 6       울산  Ulsan   18,996,979           -     8,969,184      85,032
# 7      세종  Sejong           -            -     3,412,958     123,238
# 8    경기  Gyeonggi           -     1,464,744   66,960,619   3,629,612
# 9     강원  Gwangju           -    19,543,880    2,889,126   4,459,606
# 10   충북  Chungbuk           -            -            -    1,905,825
# 11   충남  Chungnam           -    95,984,919    8,109,385   6,396,083
# 12    전북  Jeonbuk           -     6,224,560    1,451,390   3,881,249
# ...

# %%
d = d.drop(["Unnamed: 0","계"],axis =1)

# %%
data = d.loc[17].str.replace(",","").astype(int)
data
# Out:
# 원자력    160183721
# 석탄     198101369
# LNG    146183729
# 신재생     34933738
# 유류       2320967
# 양수       3271019
# 기타       7167616
# Name: 17, dtype: int32

# %%
plt.pie(data, labels = d.columns)
# Out:
# ([<matplotlib.patches.Wedge at 0x208dfdf37f0>,
# ...
#  [Text(0.6739174008556141, 0.869387909292517, '원자력'),
#   Text(-1.0798493943980831, 0.2095836000695026, '석탄'),
#   Text(0.21460208150108778, -1.078863265949583, 'LNG'),
#   Text(1.0355711974469888, -0.37093435405501324, '신재생'),
#   Text(1.0904321649903124, -0.1447677227649182, '유류'),
#   Text(1.0944854947656968, -0.11000682591315925, '양수'),
#   Text(1.0990853912978047, -0.04484754882656927, '기타')])
# C:\Users\dbtkd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\dbtkd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\dbtkd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
